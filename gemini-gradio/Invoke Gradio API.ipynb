# %%
# !pip install gradio client==1.2.0
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement client==1.2.0 (from versions: none)
# ERROR: No matching distribution found for client==1.2.0

# %%
url = ""

# %%
input_data = {"query": "what is makes Natural History Museums different from other types of museums?"}
input_data_json = json.dumps(input_data)

# %%
client = Client(url)

# %%
result = client.predict(input_data_json, api_name="/predict")

# %%
print(result)

# %%
type(result)

# %% [markdown]
# **To print only the results**

# %%
print(result["output"])
